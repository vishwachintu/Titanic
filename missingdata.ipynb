# %%
import pandas as pd
# %pylab inline
df = pd.read_csv('train.csv')
df[df.Age.isnull()]
# Out:
# Populating the interactive namespace from numpy and matplotlib
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# ...

# %%
df.Age.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e79b8d3c5226> in <module>()
# ----> 1 df.Age.mean()
#
# NameError: name 'df' is not defined

# %%
df.Age = df.Age.fillna(value=avgAge)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1a6b7b297b26> in <module>()
# ----> 1 df.Age = df.Age.fillna(value=avgAge)
#
# NameError: name 'df' is not defined

# %%
df[df.Age.isnull()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a835d6746134> in <module>()
# ----> 1 df[df.Age.isnull()]
#
# NameError: name 'df' is not defined

# %%
df.Age.plot(kind='bar',figsize=(20,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-95dc65c3da60> in <module>()
# ----> 1 df.Age.plot(kind='bar',figsize=(20,10))
#
# NameError: name 'df' is not defined

# %%
#male and female.
fig, axs = plt.subplots(1,2)

df[df.Sex=='male'].Age.value_counts().plot(kind='barh',ax=axs[0],title='Male survived', figsize=(20,10), color='red')
df[df.Sex=='female'].Age.value_counts().plot(kind='barh',ax=axs[1],title='Female survived',figsize=(20,10))
